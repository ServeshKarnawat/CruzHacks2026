# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("arm_stability_data.csv")
df = pd.DataFrame(df)
df
# Out:
#     Timestamp  Flex_Value  Accel_X  Accel_Y  Accel_Z  Intensity Direction
# 0    09:25:56       109.7   -0.007   -0.002    0.497     0.0008     STILL
# 1    09:25:56       109.5   -0.007   -0.002    0.497     0.0005     STILL
# 2    09:25:57       109.4   -0.007   -0.002    0.497     0.0006     STILL
# 3    09:25:57       109.3   -0.006   -0.002    0.497     0.0005     STILL
# 4    09:25:57       109.5   -0.006   -0.002    0.498     0.0013     STILL
# ..        ...         ...      ...      ...      ...        ...       ...
# 512  09:26:35       110.0   -0.002   -0.015    0.496     0.0002     STILL
# 513  09:26:35       110.2   -0.002   -0.015    0.497     0.0003     STILL
# 514  09:26:35       110.3   -0.002   -0.015    0.497     0.0003     STILL
# 515  09:26:35       110.3   -0.002   -0.015    0.496     0.0003     STILL
# 516  09:26:35       110.4   -0.002   -0.015    0.496     0.0001     STILL
#
# [517 rows x 7 columns]

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection='3d')

ax.scatter(df['Accel_X'], df["Accel_Y"], df['Accel_Z'], c=df['Accel_Z'], s=100)
ax.set_xlabel("X Acceleration")
ax.set_ylabel("Y Acceleration")
ax.set_zlabel("Z Acceleration")

plt.tight_layout()
plt.show()

# %%
df2 = pd.read_csv("arm_stability_data2.csv")
df2 = pd.DataFrame(df)
df2
# Out:
#     Timestamp  Flex_Value  Accel_X  Accel_Y  Accel_Z  Intensity Direction
# 0    09:25:56       109.7   -0.007   -0.002    0.497     0.0008     STILL
# 1    09:25:56       109.5   -0.007   -0.002    0.497     0.0005     STILL
# 2    09:25:57       109.4   -0.007   -0.002    0.497     0.0006     STILL
# 3    09:25:57       109.3   -0.006   -0.002    0.497     0.0005     STILL
# 4    09:25:57       109.5   -0.006   -0.002    0.498     0.0013     STILL
# ..        ...         ...      ...      ...      ...        ...       ...
# 512  09:26:35       110.0   -0.002   -0.015    0.496     0.0002     STILL
# 513  09:26:35       110.2   -0.002   -0.015    0.497     0.0003     STILL
# 514  09:26:35       110.3   -0.002   -0.015    0.497     0.0003     STILL
# 515  09:26:35       110.3   -0.002   -0.015    0.496     0.0003     STILL
# 516  09:26:35       110.4   -0.002   -0.015    0.496     0.0001     STILL
#
# [517 rows x 7 columns]

# %%
df2_chop = df[::2]
df2_chop
# Out:
#     Timestamp  Flex_Value  Accel_X  Accel_Y  Accel_Z  Intensity Direction
# 0    09:25:56       109.7   -0.007   -0.002    0.497     0.0008     STILL
# 2    09:25:57       109.4   -0.007   -0.002    0.497     0.0006     STILL
# 4    09:25:57       109.5   -0.006   -0.002    0.498     0.0013     STILL
# 6    09:25:57       109.9   -0.005   -0.003    0.496     0.0004     STILL
# 8    09:25:57       109.7   -0.005   -0.003    0.496     0.0004     STILL
# ..        ...         ...      ...      ...      ...        ...       ...
# 508  09:26:34       110.9   -0.002   -0.015    0.496     0.0002     STILL
# 510  09:26:35       110.3   -0.002   -0.015    0.496     0.0001     STILL
# 512  09:26:35       110.0   -0.002   -0.015    0.496     0.0002     STILL
# 514  09:26:35       110.3   -0.002   -0.015    0.497     0.0003     STILL
# 516  09:26:35       110.4   -0.002   -0.015    0.496     0.0001     STILL
#
# [259 rows x 7 columns]

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection='3d')

ax.scatter(df['Accel_X'], df["Accel_Y"], df['Accel_Z'], c=df['Accel_Z'], s=20)
ax.set_xlabel("X Acceleration")
ax.set_ylabel("Y Acceleration")
ax.set_zlabel("Z Acceleration")

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111,projection='3d')

ax.scatter(df2_chop['Accel_X'], df2_chop["Accel_Y"], df2_chop['Accel_Z'], c=df2_chop['Accel_Z'], s=20)
ax.set_xlabel("X Acceleration")
ax.set_ylabel("Y Acceleration")
ax.set_zlabel("Z Acceleration")

plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("arm_stability_data2.csv")
df["Magnitude"] = np.sqrt((df["Accel_X"]**2)+(df["Accel_Y"]**2)+(df['Accel_Z']**2))
df[1::100]
# Out:
#      Timestamp  Flex_Value  Accel_X  Accel_Y  Accel_Z  Intensity Direction  \
# 1     10:39:41        98.7   -0.000   -0.000    0.000     0.0000     STILL
# 101   10:39:49       102.8   -0.000   -0.000    0.000     0.0000     STILL
# 201   10:39:56       104.2   -0.000   -0.000    0.000     0.0000     STILL
# 301   10:40:05       104.0   -0.041   -0.059    0.508     0.0002     STILL
# 401   10:40:13       103.6    0.014   -0.134    0.495     0.0026     STILL
# 501   10:40:20       103.2   -0.022   -0.107    0.478     0.0138      DOWN
# 601   10:40:28       103.7   -0.028   -0.048    0.514     0.0093     STILL
# 701   10:40:35       103.1   -0.049   -0.006    0.505     0.0034     STILL
# 801   10:40:43       102.6    0.020    0.377    0.232     0.0110      DOWN
# 901   10:40:50       104.3   -0.035   -0.055    0.508     0.0003     STILL
# 1001  10:40:58       104.1   -0.033   -0.053    0.507     0.0002     STILL
# ...

# %%
x = sns.barplot(data=df[::100], x='Timestamp', y='Magnitude', palette="mako", legend='False')
# Out:
# /var/folders/7c/m2cm3_110pb0v8hktzqzlbk40000gn/T/ipykernel_50445/2827332548.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   x = sns.barplot(data=df[::100], x='Timestamp', y='Magnitude', palette="mako", legend='False')

# %%
x = sns.lineplot(data=df[::100], x='Timestamp', y='Flex_Value', palette="mako", legend='auto')
# Out:
# /var/folders/7c/m2cm3_110pb0v8hktzqzlbk40000gn/T/ipykernel_50445/3665244808.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   x = sns.lineplot(data=df[::100], x='Timestamp', y='Flex_Value', palette="mako", legend='auto')
